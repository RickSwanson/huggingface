# %% [markdown]
# ### app.ipynb

# %% [markdown]
# ###Figure 4-8

# %%
from transformers import pipeline

# %% [markdown]
# #create a pipeline instance with a tokenizer and model

# %%
roberta_pipe = pipeline(
    "sentiment-analysis",
    model="siebert/sentiment-roberta-large-english",
    tokenizer="siebert/sentiment-roberta-large-english",
    return_all_scores = True
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Device set to use cpu
# /Users/Shared/git/huggingface/venv/lib/python3.12/site-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]

# %% [markdown]
# #analyze the sentiment for the 3 sentences we used in the preceding example

# %%
roberta_pipe(sentences)
# Out:
# [[{'label': 'NEGATIVE', 'score': 0.9946781396865845},
#   {'label': 'POSITIVE', 'score': 0.005321897100657225}],
#  [{'label': 'NEGATIVE', 'score': 0.0016515370225533843},
#   {'label': 'POSITIVE', 'score': 0.9983484745025635}],
#  [{'label': 'NEGATIVE', 'score': 0.9994981288909912},
#   {'label': 'POSITIVE', 'score': 0.0005018310621380806}]]
